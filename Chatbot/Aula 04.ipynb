# %%
# Instalação biblioteca Groq
# !pip install groq

# %%
# !pip install gradio

# %%
# Importando a biblioteca do google colab para
from google.colab import userdata
api_chat2 = userdata.get('api_chat26')

# %%
#chat_api

# %%
import gradio as gr # importa a biblioteca gradio
from groq import Groq # importa a biblioteca groq

# %%
# cria um client para receber o modelo LLM
client = Groq(
    api_key=api_chat2
)
#criar uma função chamada assistennte agricultura
def assistente_agricultura(user_prompt:str) ->str:

  try:
    if user_prompt.strip()=="15":
      return "Encerrando o chatbot"

    completion = client.chat.completions.create(
      model="llama-3.1-8b-instant",
      messages=[
          {"role":"system","content":"Você é um assistente de agricultura."},
          {"role":"user","content":user_prompt},
          ],
      temperature=0,
      max_tokens=1024,
      top_p=1,
      stream=False
    )
    #No Gradio devolva a resposta
    return completion.choices[0].message.content
  except Exception as e:
    print("\n Erro no assistente de agricultura")
    return f"Erro:{e}"

  # cria a interface
iface = gr.Interface(
    fn=assistente_agricultura,
    inputs=gr.Textbox(lines=10,placeholder="Digite sua pergunta sobre agricultura"),
    outputs=gr.Textbox(lines = 10,label="Resposta"),
    title="Assistente de Agricultura",
    description="Digite sua pergunta sobre agricultura e receba respostas da LLM especialista",
    live = False
)

if __name__ == "__main__":
  iface.launch(debug=True,show_error=True)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://b5596884296235a138.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b5596884296235a138.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Created dataset file at: .gradio/flagged/dataset1.csv
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> None
# Killing tunnel 127.0.0.1:7861 <> https://b5596884296235a138.gradio.live
